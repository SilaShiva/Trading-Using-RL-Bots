# %% [markdown]
# # Import Dependencies

# %%
# Gym - (For Trading)
import gym
import gym_anytrading

# Stable baselines - (RL Algorithms)
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import PPO

# Processing libraries
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # Reading Data

# %%
df = pd.read_csv('data/gmedata.csv')

# %%
df.head()
# Out:
#          Date    Open    High     Low   Close      Volume
# 0  04/04/2022  166.98  173.24  156.51  170.73   4,640,077
# 1  04/01/2022  188.90  189.77  155.26  165.00  13,189,560
# 2  03/31/2022  163.10  175.75  158.51  166.58  11,242,230
# 3  03/30/2022  175.00  183.34  165.00  166.85   9,169,186
# 4  03/29/2022  188.24  199.41  163.00  179.90  18,011,490

# %%
len(df)
# Out:
# 254

# %%
df.dtypes
# Out:
# Date       object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume     object
# dtype: object

# %%
#Checking Null Values
df.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
# We convert Date column type to datetime64 so it will run with gym_anytraing
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Date      datetime64[ns]
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume            object
# dtype: object

# %%
# We set Date column as Index
df.set_index('Date', inplace=True)
df.head()
# Out:
#               Open    High     Low   Close      Volume
# Date
# 2022-04-04  166.98  173.24  156.51  170.73   4,640,077
# 2022-04-01  188.90  189.77  155.26  165.00  13,189,560
# 2022-03-31  163.10  175.75  158.51  166.58  11,242,230
# 2022-03-30  175.00  183.34  165.00  166.85   9,169,186
# 2022-03-29  188.24  199.41  163.00  179.90  18,011,490

# %%
# Passing Agent through the Trading Environment(stocks)
env = gym.make('stocks-v0', df = df, frame_bound = (5,250), window_size = 5)
## window_size(Agent takes this as reference to take decisions)
## frame_bound(Amount of data)

# %%
# Real prices over time. Used to calculate profit and render the environment.
env.prices
# Out:
# array([170.73, 165.  , 166.58, 166.85, 179.9 , 189.59, 151.95, 142.39,
#        141.  , 123.14,  94.2 ,  90.79,  87.7 ,  86.86,  82.64,  78.11,
#         92.69, 100.56, 105.21, 103.01,  99.35, 111.66, 118.41, 121.97,
#        119.02, 123.34, 118.58, 124.58, 114.87, 118.06, 121.53, 123.41,
#        128.33, 126.16, 117.09, 124.25, 122.47, 124.29, 115.6 , 102.34,
#        102.34,  99.23, 100.04, 112.6 , 108.93,  97.91,  93.52, 103.26,
#         99.79, 100.15, 106.36, 102.67, 106.57, 108.91, 116.65, 122.48,
#        128.06, 130.3 , 131.15, 140.62, 131.03, 129.37, 148.91, 152.84,
#        148.39, 155.33, 153.93, 146.46, 148.31, 152.14, 154.  , 158.12,
#        157.14, 155.64, 144.59, 148.59, 147.69, 136.88, 159.01, 155.76,
#        173.65, 177.81, 167.12, 172.39, 181.56, 179.84, 196.21, 202.01,
#        199.72, 211.78, 213.9 , 247.55, 228.8 , 210.12, 210.  , 207.18,
#        209.14, 202.1 , 204.32, 199.19, 206.6 , 218.64, 213.25, 217.84,
#        218.33, 206.99, 200.09, 183.51, 182.85, 173.51, 177.84, 173.97,
#        169.8 , 181.71, 184.52, 186.79, 186.02, 183.28, 183.83, 184.06,
#        175.82, 178.1 , 172.68, 172.12, 171.07, 172.18, 171.36, 176.91,
#        175.47, 175.92, 178.6 , 189.48, 185.16, 191.24, 190.14, 189.95,
#        192.2 , 204.97, 206.37, 204.52, 199.24, 203.4 , 190.41, 199.18,
#        198.8 , 199.  , 202.75, 213.52, 212.97, 218.24, 209.2 , 204.95,
#        205.22, 199.65, 210.29, 164.89, 159.3 , 152.9 , 157.05, 163.55,
#        163.93, 162.52, 162.35, 158.78, 159.05, 161.13, 151.77, 153.44,
#        146.8 , 152.75, 157.65, 161.12, 164.86, 169.12, 178.54, 183.94,
#        180.36, 178.85, 185.81, 191.18, 173.49, 169.04, 166.82, 167.62,
#        180.06, 189.25, 191.23, 191.38, 190.66, 199.56, 202.83, 204.36,
#        214.14, 210.88, 213.25, 209.51, 212.31, 219.34, 220.4 , 200.37,
#        213.82, 223.59, 222.97, 222.5 , 229.44, 233.34, 220.39, 302.56,
#        300.  , 280.01, 248.36, 258.18, 282.24, 249.02, 222.  , 254.13,
#        242.56, 209.43, 180.01, 176.79, 170.49, 168.83, 180.67, 180.6 ,
#        159.92, 164.5 , 144.79, 146.92, 143.22, 161.11, 161.01, 159.48,
#        160.73, 162.2 , 173.59, 176.19, 178.58, 177.77, 168.93, 151.18,
#        151.17, 158.51, 158.53, 164.37, 154.69, 156.44, 166.53, 140.99,
#        141.09, 158.36])

# %%
# Extracted features over time. Used to create Gym observations.
## It subtracts with previous value
env.signal_features
# Out:
# array([[ 1.7073e+02,  0.0000e+00],
#        [ 1.6500e+02, -5.7300e+00],
#        [ 1.6658e+02,  1.5800e+00],
#        [ 1.6685e+02,  2.7000e-01],
#        [ 1.7990e+02,  1.3050e+01],
#        [ 1.8959e+02,  9.6900e+00],
#        [ 1.5195e+02, -3.7640e+01],
#        [ 1.4239e+02, -9.5600e+00],
#        [ 1.4100e+02, -1.3900e+00],
#        [ 1.2314e+02, -1.7860e+01],
#        [ 9.4200e+01, -2.8940e+01],
#        [ 9.0790e+01, -3.4100e+00],
#        [ 8.7700e+01, -3.0900e+00],
#        [ 8.6860e+01, -8.4000e-01],
#        [ 8.2640e+01, -4.2200e+00],
#        [ 7.8110e+01, -4.5300e+00],
#        [ 9.2690e+01,  1.4580e+01],
#        [ 1.0056e+02,  7.8700e+00],
#        [ 1.0521e+02,  4.6500e+00],
#        [ 1.0301e+02, -2.2000e+00],
#        [ 9.9350e+01, -3.6600e+00],
#        [ 1.1166e+02,  1.2310e+01],
#        [ 1.1841e+02,  6.7500e+00],
#        [ 1.2197e+02,  3.5600e+00],
#        [ 1.1902e+02, -2.9500e+00],
#        [ 1.2334e+02,  4.3200e+00],
#        [ 1.1858e+02, -4.7600e+00],
#        [ 1.2458e+02,  6.0000e+00],
#        [ 1.1487e+02, -9.7100e+00],
#        [ 1.1806e+02,  3.1900e+00],
#        [ 1.2153e+02,  3.4700e+00],
#        [ 1.2341e+02,  1.8800e+00],
#        [ 1.2833e+02,  4.9200e+00],
#        [ 1.2616e+02, -2.1700e+00],
#        [ 1.1709e+02, -9.0700e+00],
#        [ 1.2425e+02,  7.1600e+00],
#        [ 1.2247e+02, -1.7800e+00],
#        [ 1.2429e+02,  1.8200e+00],
#        [ 1.1560e+02, -8.6900e+00],
#        [ 1.0234e+02, -1.3260e+01],
#        [ 1.0234e+02,  0.0000e+00],
#        [ 9.9230e+01, -3.1100e+00],
#        [ 1.0004e+02,  8.1000e-01],
#        [ 1.1260e+02,  1.2560e+01],
#        [ 1.0893e+02, -3.6700e+00],
#        [ 9.7910e+01, -1.1020e+01],
#        [ 9.3520e+01, -4.3900e+00],
#        [ 1.0326e+02,  9.7400e+00],
#        [ 9.9790e+01, -3.4700e+00],
#        [ 1.0015e+02,  3.6000e-01],
#        [ 1.0636e+02,  6.2100e+00],
#        [ 1.0267e+02, -3.6900e+00],
#        [ 1.0657e+02,  3.9000e+00],
#        [ 1.0891e+02,  2.3400e+00],
#        [ 1.1665e+02,  7.7400e+00],
#        [ 1.2248e+02,  5.8300e+00],
#        [ 1.2806e+02,  5.5800e+00],
#        [ 1.3030e+02,  2.2400e+00],
#        [ 1.3115e+02,  8.5000e-01],
#        [ 1.4062e+02,  9.4700e+00],
#        [ 1.3103e+02, -9.5900e+00],
#        [ 1.2937e+02, -1.6600e+00],
#        [ 1.4891e+02,  1.9540e+01],
#        [ 1.5284e+02,  3.9300e+00],
#        [ 1.4839e+02, -4.4500e+00],
#        [ 1.5533e+02,  6.9400e+00],
#        [ 1.5393e+02, -1.4000e+00],
#        [ 1.4646e+02, -7.4700e+00],
#        [ 1.4831e+02,  1.8500e+00],
#        [ 1.5214e+02,  3.8300e+00],
#        [ 1.5400e+02,  1.8600e+00],
#        [ 1.5812e+02,  4.1200e+00],
#        [ 1.5714e+02, -9.8000e-01],
#        [ 1.5564e+02, -1.5000e+00],
#        [ 1.4459e+02, -1.1050e+01],
#        [ 1.4859e+02,  4.0000e+00],
#        [ 1.4769e+02, -9.0000e-01],
#        [ 1.3688e+02, -1.0810e+01],
#        [ 1.5901e+02,  2.2130e+01],
#        [ 1.5576e+02, -3.2500e+00],
#        [ 1.7365e+02,  1.7890e+01],
#        [ 1.7781e+02,  4.1600e+00],
#        [ 1.6712e+02, -1.0690e+01],
#        [ 1.7239e+02,  5.2700e+00],
#        [ 1.8156e+02,  9.1700e+00],
#        [ 1.7984e+02, -1.7200e+00],
#        [ 1.9621e+02,  1.6370e+01],
#        [ 2.0201e+02,  5.8000e+00],
#        [ 1.9972e+02, -2.2900e+00],
#        [ 2.1178e+02,  1.2060e+01],
#        [ 2.1390e+02,  2.1200e+00],
#        [ 2.4755e+02,  3.3650e+01],
#        [ 2.2880e+02, -1.8750e+01],
#        [ 2.1012e+02, -1.8680e+01],
#        [ 2.1000e+02, -1.2000e-01],
#        [ 2.0718e+02, -2.8200e+00],
#        [ 2.0914e+02,  1.9600e+00],
#        [ 2.0210e+02, -7.0400e+00],
#        [ 2.0432e+02,  2.2200e+00],
#        [ 1.9919e+02, -5.1300e+00],
#        [ 2.0660e+02,  7.4100e+00],
#        [ 2.1864e+02,  1.2040e+01],
#        [ 2.1325e+02, -5.3900e+00],
#        [ 2.1784e+02,  4.5900e+00],
#        [ 2.1833e+02,  4.9000e-01],
#        [ 2.0699e+02, -1.1340e+01],
#        [ 2.0009e+02, -6.9000e+00],
#        [ 1.8351e+02, -1.6580e+01],
#        [ 1.8285e+02, -6.6000e-01],
#        [ 1.7351e+02, -9.3400e+00],
#        [ 1.7784e+02,  4.3300e+00],
#        [ 1.7397e+02, -3.8700e+00],
#        [ 1.6980e+02, -4.1700e+00],
#        [ 1.8171e+02,  1.1910e+01],
#        [ 1.8452e+02,  2.8100e+00],
#        [ 1.8679e+02,  2.2700e+00],
#        [ 1.8602e+02, -7.7000e-01],
#        [ 1.8328e+02, -2.7400e+00],
#        [ 1.8383e+02,  5.5000e-01],
#        [ 1.8406e+02,  2.3000e-01],
#        [ 1.7582e+02, -8.2400e+00],
#        [ 1.7810e+02,  2.2800e+00],
#        [ 1.7268e+02, -5.4200e+00],
#        [ 1.7212e+02, -5.6000e-01],
#        [ 1.7107e+02, -1.0500e+00],
#        [ 1.7218e+02,  1.1100e+00],
#        [ 1.7136e+02, -8.2000e-01],
#        [ 1.7691e+02,  5.5500e+00],
#        [ 1.7547e+02, -1.4400e+00],
#        [ 1.7592e+02,  4.5000e-01],
#        [ 1.7860e+02,  2.6800e+00],
#        [ 1.8948e+02,  1.0880e+01],
#        [ 1.8516e+02, -4.3200e+00],
#        [ 1.9124e+02,  6.0800e+00],
#        [ 1.9014e+02, -1.1000e+00],
#        [ 1.8995e+02, -1.9000e-01],
#        [ 1.9220e+02,  2.2500e+00],
#        [ 2.0497e+02,  1.2770e+01],
#        [ 2.0637e+02,  1.4000e+00],
#        [ 2.0452e+02, -1.8500e+00],
#        [ 1.9924e+02, -5.2800e+00],
#        [ 2.0340e+02,  4.1600e+00],
#        [ 1.9041e+02, -1.2990e+01],
#        [ 1.9918e+02,  8.7700e+00],
#        [ 1.9880e+02, -3.8000e-01],
#        [ 1.9900e+02,  2.0000e-01],
#        [ 2.0275e+02,  3.7500e+00],
#        [ 2.1352e+02,  1.0770e+01],
#        [ 2.1297e+02, -5.5000e-01],
#        [ 2.1824e+02,  5.2700e+00],
#        [ 2.0920e+02, -9.0400e+00],
#        [ 2.0495e+02, -4.2500e+00],
#        [ 2.0522e+02,  2.7000e-01],
#        [ 1.9965e+02, -5.5700e+00],
#        [ 2.1029e+02,  1.0640e+01],
#        [ 1.6489e+02, -4.5400e+01],
#        [ 1.5930e+02, -5.5900e+00],
#        [ 1.5290e+02, -6.4000e+00],
#        [ 1.5705e+02,  4.1500e+00],
#        [ 1.6355e+02,  6.5000e+00],
#        [ 1.6393e+02,  3.8000e-01],
#        [ 1.6252e+02, -1.4100e+00],
#        [ 1.6235e+02, -1.7000e-01],
#        [ 1.5878e+02, -3.5700e+00],
#        [ 1.5905e+02,  2.7000e-01],
#        [ 1.6113e+02,  2.0800e+00],
#        [ 1.5177e+02, -9.3600e+00],
#        [ 1.5344e+02,  1.6700e+00],
#        [ 1.4680e+02, -6.6400e+00],
#        [ 1.5275e+02,  5.9500e+00],
#        [ 1.5765e+02,  4.9000e+00],
#        [ 1.6112e+02,  3.4700e+00],
#        [ 1.6486e+02,  3.7400e+00],
#        [ 1.6912e+02,  4.2600e+00],
#        [ 1.7854e+02,  9.4200e+00],
#        [ 1.8394e+02,  5.4000e+00],
#        [ 1.8036e+02, -3.5800e+00],
#        [ 1.7885e+02, -1.5100e+00],
#        [ 1.8581e+02,  6.9600e+00],
#        [ 1.9118e+02,  5.3700e+00],
#        [ 1.7349e+02, -1.7690e+01],
#        [ 1.6904e+02, -4.4500e+00],
#        [ 1.6682e+02, -2.2200e+00],
#        [ 1.6762e+02,  8.0000e-01],
#        [ 1.8006e+02,  1.2440e+01],
#        [ 1.8925e+02,  9.1900e+00],
#        [ 1.9123e+02,  1.9800e+00],
#        [ 1.9138e+02,  1.5000e-01],
#        [ 1.9066e+02, -7.2000e-01],
#        [ 1.9956e+02,  8.9000e+00],
#        [ 2.0283e+02,  3.2700e+00],
#        [ 2.0436e+02,  1.5300e+00],
#        [ 2.1414e+02,  9.7800e+00],
#        [ 2.1088e+02, -3.2600e+00],
#        [ 2.1325e+02,  2.3700e+00],
#        [ 2.0951e+02, -3.7400e+00],
#        [ 2.1231e+02,  2.8000e+00],
#        [ 2.1934e+02,  7.0300e+00],
#        [ 2.2040e+02,  1.0600e+00],
#        [ 2.0037e+02, -2.0030e+01],
#        [ 2.1382e+02,  1.3450e+01],
#        [ 2.2359e+02,  9.7700e+00],
#        [ 2.2297e+02, -6.2000e-01],
#        [ 2.2250e+02, -4.7000e-01],
#        [ 2.2944e+02,  6.9400e+00],
#        [ 2.3334e+02,  3.9000e+00],
#        [ 2.2039e+02, -1.2950e+01],
#        [ 3.0256e+02,  8.2170e+01],
#        [ 3.0000e+02, -2.5600e+00],
#        [ 2.8001e+02, -1.9990e+01],
#        [ 2.4836e+02, -3.1650e+01],
#        [ 2.5818e+02,  9.8200e+00],
#        [ 2.8224e+02,  2.4060e+01],
#        [ 2.4902e+02, -3.3220e+01],
#        [ 2.2200e+02, -2.7020e+01],
#        [ 2.5413e+02,  3.2130e+01],
#        [ 2.4256e+02, -1.1570e+01],
#        [ 2.0943e+02, -3.3130e+01],
#        [ 1.8001e+02, -2.9420e+01],
#        [ 1.7679e+02, -3.2200e+00],
#        [ 1.7049e+02, -6.3000e+00],
#        [ 1.6883e+02, -1.6600e+00],
#        [ 1.8067e+02,  1.1840e+01],
#        [ 1.8060e+02, -7.0000e-02],
#        [ 1.5992e+02, -2.0680e+01],
#        [ 1.6450e+02,  4.5800e+00],
#        [ 1.4479e+02, -1.9710e+01],
#        [ 1.4692e+02,  2.1300e+00],
#        [ 1.4322e+02, -3.7000e+00],
#        [ 1.6111e+02,  1.7890e+01],
#        [ 1.6101e+02, -1.0000e-01],
#        [ 1.5948e+02, -1.5300e+00],
#        [ 1.6073e+02,  1.2500e+00],
#        [ 1.6220e+02,  1.4700e+00],
#        [ 1.7359e+02,  1.1390e+01],
#        [ 1.7619e+02,  2.6000e+00],
#        [ 1.7858e+02,  2.3900e+00],
#        [ 1.7777e+02, -8.1000e-01],
#        [ 1.6893e+02, -8.8400e+00],
#        [ 1.5118e+02, -1.7750e+01],
#        [ 1.5117e+02, -1.0000e-02],
#        [ 1.5851e+02,  7.3400e+00],
#        [ 1.5853e+02,  2.0000e-02],
#        [ 1.6437e+02,  5.8400e+00],
#        [ 1.5469e+02, -9.6800e+00],
#        [ 1.5644e+02,  1.7500e+00],
#        [ 1.6653e+02,  1.0090e+01],
#        [ 1.4099e+02, -2.5540e+01],
#        [ 1.4109e+02,  1.0000e-01],
#        [ 1.5836e+02,  1.7270e+01]])

# %% [markdown]
# # Building Environment and Training

# %%
## It gives value 2 as its actions are buying and selling
env.action_space
# Out:
# Discrete(2)

# %%
# Passing Agent to Stocks Environment
env_maker = lambda: gym.make('stocks-v0', df = df, frame_bound = (5,250), window_size = 5)
env = DummyVecEnv([env_maker])

# %%
# Training Agent to Environment
model = PPO('MlpPolicy', env, verbose = 1) 
model.learn(total_timesteps = 1000000)
## We are going to run this Model till 'explained_variance' is close to 1 and 'value_loss' should be low as possible
# Out:
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 7984 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 5070        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011521708 |
# |    clip_fraction        | 0.0584      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.678      |
# |    explained_variance   | -0.000205   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 204         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00409    |
# |    value_loss           | 393         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4526         |
# |    iterations           | 3            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0030724956 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.673       |
# |    explained_variance   | 0.0154       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 171          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.0013      |
# |    value_loss           | 442          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 4300         |
# |    iterations           | 4            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0018175808 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.668       |
# |    explained_variance   | 0.0275       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 215          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000897    |
# |    value_loss           | 575          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4145        |
# |    iterations           | 5           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008995438 |
# |    clip_fraction        | 0.0339      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.641      |
# |    explained_variance   | 0.0395      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 150         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00237    |
# |    value_loss           | 356         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3985         |
# |    iterations           | 6            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0032637645 |
# |    clip_fraction        | 0.00918      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.61        |
# |    explained_variance   | 0.0553       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 271          |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00152     |
# |    value_loss           | 447          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3893         |
# |    iterations           | 7            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0029438362 |
# |    clip_fraction        | 0.00381      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.629       |
# |    explained_variance   | 0.0538       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 228          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000412    |
# |    value_loss           | 469          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3854         |
# |    iterations           | 8            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0060917838 |
# |    clip_fraction        | 0.00513      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.652       |
# |    explained_variance   | 0.08         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 155          |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 456          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3809         |
# |    iterations           | 9            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0075463057 |
# |    clip_fraction        | 0.00815      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.636       |
# |    explained_variance   | 0.0864       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 382          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00232     |
# |    value_loss           | 561          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3800        |
# |    iterations           | 10          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.005158293 |
# |    clip_fraction        | 0.027       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.599      |
# |    explained_variance   | 0.0863      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 240         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00464    |
# |    value_loss           | 453         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3810         |
# |    iterations           | 11           |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0012690142 |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.598       |
# |    explained_variance   | 0.134        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 178          |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.000716    |
# |    value_loss           | 382          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3795         |
# |    iterations           | 12           |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0029430524 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.623       |
# |    explained_variance   | 0.145        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 249          |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0022      |
# |    value_loss           | 433          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3781         |
# |    iterations           | 13           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0036426056 |
# |    clip_fraction        | 0.00879      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.617       |
# |    explained_variance   | 0.154        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 125          |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00225     |
# |    value_loss           | 481          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3769        |
# |    iterations           | 14          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.005271323 |
# |    clip_fraction        | 0.0218      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.614      |
# |    explained_variance   | 0.169       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 196         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00407    |
# |    value_loss           | 470         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3760        |
# |    iterations           | 15          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.007718828 |
# |    clip_fraction        | 0.0647      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.646      |
# |    explained_variance   | 0.0702      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 207         |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00567    |
# |    value_loss           | 441         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3764         |
# |    iterations           | 16           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0053543746 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.63        |
# |    explained_variance   | 0.0584       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 165          |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00406     |
# |    value_loss           | 375          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3767         |
# |    iterations           | 17           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0028693038 |
# |    clip_fraction        | 0.0256       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.654       |
# |    explained_variance   | 0.1          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 206          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00318     |
# |    value_loss           | 417          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3765         |
# |    iterations           | 18           |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0024825945 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.653       |
# |    explained_variance   | 0.066        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 160          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00272     |
# |    value_loss           | 364          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3763         |
# |    iterations           | 19           |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0064257677 |
# |    clip_fraction        | 0.0411       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.674       |
# |    explained_variance   | 0.119        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 164          |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00255     |
# |    value_loss           | 380          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3769        |
# |    iterations           | 20          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011358086 |
# |    clip_fraction        | 0.0715      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.654      |
# |    explained_variance   | 0.112       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 199         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00522    |
# |    value_loss           | 363         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3766         |
# |    iterations           | 21           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0085629895 |
# |    clip_fraction        | 0.0698       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.66        |
# |    explained_variance   | 0.033        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 243          |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00278     |
# |    value_loss           | 452          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3757         |
# |    iterations           | 22           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0068235667 |
# |    clip_fraction        | 0.059        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.654       |
# |    explained_variance   | 0.0524       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 175          |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000742    |
# |    value_loss           | 358          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3744        |
# |    iterations           | 23          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.006122927 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.645      |
# |    explained_variance   | 0.0353      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 233         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00212    |
# |    value_loss           | 443         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3739       |
# |    iterations           | 24         |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.00856472 |
# |    clip_fraction        | 0.0886     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.627     |
# |    explained_variance   | 0.0414     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 431        |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.00281   |
# |    value_loss           | 583        |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3732         |
# |    iterations           | 25           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0042273547 |
# |    clip_fraction        | 0.047        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.625       |
# |    explained_variance   | 0.0491       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 178          |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 0.000648     |
# |    value_loss           | 472          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3734         |
# |    iterations           | 26           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0057800794 |
# |    clip_fraction        | 0.0712       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.621       |
# |    explained_variance   | 0.0394       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 251          |
# |    n_updates            | 250          |
# |    policy_gradient_loss | 8.29e-05     |
# |    value_loss           | 600          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3734         |
# |    iterations           | 27           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0031375738 |
# |    clip_fraction        | 0.0558       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.611       |
# |    explained_variance   | 0.0731       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 257          |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.000863    |
# |    value_loss           | 366          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3734         |
# |    iterations           | 28           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0064793928 |
# |    clip_fraction        | 0.0682       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.608       |
# |    explained_variance   | 0.056        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 267          |
# |    n_updates            | 270          |
# |    policy_gradient_loss | 0.00205      |
# |    value_loss           | 511          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3734         |
# |    iterations           | 29           |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0038010858 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.605       |
# |    explained_variance   | 0.0524       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 270          |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 463          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3727         |
# |    iterations           | 30           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0050068144 |
# |    clip_fraction        | 0.0727       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.602       |
# |    explained_variance   | 0.0764       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 176          |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 327          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3724        |
# |    iterations           | 31          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.007040306 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.598      |
# |    explained_variance   | 0.0633      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 292         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00013    |
# |    value_loss           | 436         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3720         |
# |    iterations           | 32           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0051688487 |
# |    clip_fraction        | 0.0428       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.589       |
# |    explained_variance   | 0.0732       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 174          |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00206     |
# |    value_loss           | 418          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3721         |
# |    iterations           | 33           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0037530805 |
# |    clip_fraction        | 0.0502       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.581       |
# |    explained_variance   | 0.0832       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 192          |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000944    |
# |    value_loss           | 449          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3726         |
# |    iterations           | 34           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0055912714 |
# |    clip_fraction        | 0.058        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.582       |
# |    explained_variance   | 0.0736       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 280          |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -4.51e-05    |
# |    value_loss           | 473          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3721        |
# |    iterations           | 35          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009518739 |
# |    clip_fraction        | 0.0908      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.561      |
# |    explained_variance   | 0.0411      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 345         |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00297    |
# |    value_loss           | 545         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3718         |
# |    iterations           | 36           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0068379487 |
# |    clip_fraction        | 0.066        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.55        |
# |    explained_variance   | 0.0708       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 221          |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00218     |
# |    value_loss           | 492          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3717        |
# |    iterations           | 37          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.004974056 |
# |    clip_fraction        | 0.0524      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.536      |
# |    explained_variance   | 0.0532      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 193         |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00039    |
# |    value_loss           | 494         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3716         |
# |    iterations           | 38           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0062943315 |
# |    clip_fraction        | 0.0637       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.528       |
# |    explained_variance   | 0.0665       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 184          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00117     |
# |    value_loss           | 596          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3716        |
# |    iterations           | 39          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.007238367 |
# |    clip_fraction        | 0.056       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.53       |
# |    explained_variance   | 0.0812      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 410         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.000182   |
# |    value_loss           | 610         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3715       |
# |    iterations           | 40         |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.00468968 |
# |    clip_fraction        | 0.0588     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.487     |
# |    explained_variance   | 0.0748     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 263        |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.00133   |
# |    value_loss           | 608        |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3716         |
# |    iterations           | 41           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0071338983 |
# |    clip_fraction        | 0.0755       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.475       |
# |    explained_variance   | 0.0805       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 277          |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 0.000721     |
# |    value_loss           | 520          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3721         |
# |    iterations           | 42           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0029546348 |
# |    clip_fraction        | 0.0446       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.476       |
# |    explained_variance   | 0.1          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 272          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | 0.000911     |
# |    value_loss           | 651          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3724         |
# |    iterations           | 43           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0031415902 |
# |    clip_fraction        | 0.0528       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.474       |
# |    explained_variance   | 0.105        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 223          |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.000327    |
# |    value_loss           | 542          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3725        |
# |    iterations           | 44          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.007072953 |
# |    clip_fraction        | 0.0649      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.465      |
# |    explained_variance   | 0.118       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 410         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00104    |
# |    value_loss           | 624         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3722         |
# |    iterations           | 45           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0020350176 |
# |    clip_fraction        | 0.0374       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.472       |
# |    explained_variance   | 0.13         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 220          |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.000487    |
# |    value_loss           | 622          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3724         |
# |    iterations           | 46           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0033419537 |
# |    clip_fraction        | 0.0646       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.469       |
# |    explained_variance   | 0.119        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 267          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | 0.00182      |
# |    value_loss           | 633          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3728        |
# |    iterations           | 47          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.005243067 |
# |    clip_fraction        | 0.0392      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.464      |
# |    explained_variance   | 0.149       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 366         |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.000961   |
# |    value_loss           | 736         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3725         |
# |    iterations           | 48           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0063950275 |
# |    clip_fraction        | 0.0464       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.462       |
# |    explained_variance   | 0.13         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 300          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00046     |
# |    value_loss           | 567          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3719        |
# |    iterations           | 49          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.005787512 |
# |    clip_fraction        | 0.0525      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.45       |
# |    explained_variance   | 0.149       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 334         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00106    |
# |    value_loss           | 661         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3718        |
# |    iterations           | 50          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.005112972 |
# |    clip_fraction        | 0.0571      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.461      |
# |    explained_variance   | 0.142       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 176         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.00234    |
# |    value_loss           | 675         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3716         |
# |    iterations           | 51           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0035980772 |
# |    clip_fraction        | 0.0406       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.461       |
# |    explained_variance   | 0.134        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 384          |
# |    n_updates            | 500          |
# |    policy_gradient_loss | 0.00113      |
# |    value_loss           | 672          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3716         |
# |    iterations           | 52           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0056306855 |
# |    clip_fraction        | 0.0531       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.442       |
# |    explained_variance   | 0.146        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 200          |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00054     |
# |    value_loss           | 645          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3715         |
# |    iterations           | 53           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0021799544 |
# |    clip_fraction        | 0.0466       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.453       |
# |    explained_variance   | 0.143        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 215          |
# |    n_updates            | 520          |
# |    policy_gradient_loss | 0.00176      |
# |    value_loss           | 573          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3712        |
# |    iterations           | 54          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.003969055 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.442      |
# |    explained_variance   | 0.14        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 374         |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.000605   |
# |    value_loss           | 702         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3712         |
# |    iterations           | 55           |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0073965066 |
# |    clip_fraction        | 0.0916       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.418       |
# |    explained_variance   | 0.147        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 250          |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00347     |
# |    value_loss           | 630          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3699        |
# |    iterations           | 56          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.005755804 |
# |    clip_fraction        | 0.0709      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.429      |
# |    explained_variance   | 0.139       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 324         |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.000474   |
# |    value_loss           | 665         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3677        |
# |    iterations           | 57          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.012863891 |
# |    clip_fraction        | 0.0789      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.431      |
# |    explained_variance   | 0.159       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 468         |
# |    n_updates            | 560         |
# |    policy_gradient_loss | 0.000839    |
# |    value_loss           | 751         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3675         |
# |    iterations           | 58           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 118784       |
# | train/                  |              |
# |    approx_kl            | 0.0075315493 |
# |    clip_fraction        | 0.0409       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.421       |
# |    explained_variance   | 0.161        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 448          |
# |    n_updates            | 570          |
# |    policy_gradient_loss | 0.000427     |
# |    value_loss           | 732          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3673         |
# |    iterations           | 59           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0053933184 |
# |    clip_fraction        | 0.087        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.413       |
# |    explained_variance   | 0.172        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 328          |
# |    n_updates            | 580          |
# |    policy_gradient_loss | 0.000395     |
# |    value_loss           | 633          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3672        |
# |    iterations           | 60          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.008339722 |
# |    clip_fraction        | 0.0861      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.407      |
# |    explained_variance   | 0.162       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 363         |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.000432   |
# |    value_loss           | 756         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3671        |
# |    iterations           | 61          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.010142472 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.407      |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 450         |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.000183   |
# |    value_loss           | 751         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3671        |
# |    iterations           | 62          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.007951531 |
# |    clip_fraction        | 0.0583      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.399      |
# |    explained_variance   | 0.195       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 290         |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.000437   |
# |    value_loss           | 587         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3670         |
# |    iterations           | 63           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 129024       |
# | train/                  |              |
# |    approx_kl            | 0.0064990274 |
# |    clip_fraction        | 0.0435       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.379       |
# |    explained_variance   | 0.167        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 488          |
# |    n_updates            | 620          |
# |    policy_gradient_loss | 0.000815     |
# |    value_loss           | 652          |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3670         |
# |    iterations           | 64           |
# |    time_elapsed         | 35           |
# ...
# |    policy_gradient_loss | -0.000642    |
# |    value_loss           | 494          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3710        |
# |    iterations           | 469         |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 960512      |
# | train/                  |             |
# |    approx_kl            | 0.020393169 |
# |    clip_fraction        | 0.0593      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.201      |
# |    explained_variance   | 0.601       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 336         |
# |    n_updates            | 4680        |
# |    policy_gradient_loss | 0.001       |
# |    value_loss           | 519         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3710        |
# |    iterations           | 470         |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 962560      |
# | train/                  |             |
# |    approx_kl            | 0.023345035 |
# |    clip_fraction        | 0.0731      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.203      |
# |    explained_variance   | 0.599       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 206         |
# |    n_updates            | 4690        |
# |    policy_gradient_loss | 0.00038     |
# |    value_loss           | 468         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3710        |
# |    iterations           | 471         |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 964608      |
# | train/                  |             |
# |    approx_kl            | 0.021363638 |
# |    clip_fraction        | 0.0529      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.207      |
# |    explained_variance   | 0.6         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 208         |
# |    n_updates            | 4700        |
# |    policy_gradient_loss | 0.00122     |
# |    value_loss           | 465         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3710        |
# |    iterations           | 472         |
# |    time_elapsed         | 260         |
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.004308571 |
# |    clip_fraction        | 0.0497      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.206      |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 180         |
# |    n_updates            | 4710        |
# |    policy_gradient_loss | 0.00246     |
# |    value_loss           | 511         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3710        |
# |    iterations           | 473         |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 968704      |
# | train/                  |             |
# |    approx_kl            | 0.005416397 |
# |    clip_fraction        | 0.0494      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.202      |
# |    explained_variance   | 0.592       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 257         |
# |    n_updates            | 4720        |
# |    policy_gradient_loss | 0.00353     |
# |    value_loss           | 489         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3710        |
# |    iterations           | 474         |
# |    time_elapsed         | 261         |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.017198456 |
# |    clip_fraction        | 0.0561      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.19       |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 320         |
# |    n_updates            | 4730        |
# |    policy_gradient_loss | 0.00472     |
# |    value_loss           | 606         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3711        |
# |    iterations           | 475         |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 972800      |
# | train/                  |             |
# |    approx_kl            | 0.021902824 |
# |    clip_fraction        | 0.0624      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.199      |
# |    explained_variance   | 0.59        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 250         |
# |    n_updates            | 4740        |
# |    policy_gradient_loss | 0.00343     |
# |    value_loss           | 545         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3711        |
# |    iterations           | 476         |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.003963677 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.198      |
# |    explained_variance   | 0.621       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 239         |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | 0.00238     |
# |    value_loss           | 507         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3710        |
# |    iterations           | 477         |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 976896      |
# | train/                  |             |
# |    approx_kl            | 0.006437999 |
# |    clip_fraction        | 0.0616      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.185      |
# |    explained_variance   | 0.615       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 119         |
# |    n_updates            | 4760        |
# |    policy_gradient_loss | 0.00571     |
# |    value_loss           | 503         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3711        |
# |    iterations           | 478         |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 978944      |
# | train/                  |             |
# |    approx_kl            | 0.015733402 |
# |    clip_fraction        | 0.0466      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.186      |
# |    explained_variance   | 0.612       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 202         |
# |    n_updates            | 4770        |
# |    policy_gradient_loss | 0.000722    |
# |    value_loss           | 490         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3711        |
# |    iterations           | 479         |
# |    time_elapsed         | 264         |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.007237264 |
# |    clip_fraction        | 0.0439      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.183      |
# |    explained_variance   | 0.61        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 281         |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | 0.00233     |
# |    value_loss           | 523         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3711        |
# |    iterations           | 480         |
# |    time_elapsed         | 264         |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.007147135 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.189      |
# |    explained_variance   | 0.613       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 245         |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | 0.00159     |
# |    value_loss           | 508         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3711       |
# |    iterations           | 481        |
# |    time_elapsed         | 265        |
# |    total_timesteps      | 985088     |
# | train/                  |            |
# |    approx_kl            | 0.02805217 |
# |    clip_fraction        | 0.0656     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.181     |
# |    explained_variance   | 0.62       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 191        |
# |    n_updates            | 4800       |
# |    policy_gradient_loss | -0.00144   |
# |    value_loss           | 488        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3711        |
# |    iterations           | 482         |
# |    time_elapsed         | 265         |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.011524206 |
# |    clip_fraction        | 0.0427      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.175      |
# |    explained_variance   | 0.614       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 187         |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.000478   |
# |    value_loss           | 518         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3711        |
# |    iterations           | 483         |
# |    time_elapsed         | 266         |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.008991426 |
# |    clip_fraction        | 0.0414      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.181      |
# |    explained_variance   | 0.61        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 216         |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.000922   |
# |    value_loss           | 483         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3712        |
# |    iterations           | 484         |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.011022544 |
# |    clip_fraction        | 0.0478      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.184      |
# |    explained_variance   | 0.61        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 287         |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.00183    |
# |    value_loss           | 529         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3712        |
# |    iterations           | 485         |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.060131185 |
# |    clip_fraction        | 0.0749      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.185      |
# |    explained_variance   | 0.591       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 198         |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | 0.0131      |
# |    value_loss           | 462         |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3711       |
# |    iterations           | 486        |
# |    time_elapsed         | 268        |
# |    total_timesteps      | 995328     |
# | train/                  |            |
# |    approx_kl            | 0.03226254 |
# |    clip_fraction        | 0.0762     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.184     |
# |    explained_variance   | 0.607      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 309        |
# |    n_updates            | 4850       |
# |    policy_gradient_loss | 0.011      |
# |    value_loss           | 465        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3712        |
# |    iterations           | 487         |
# |    time_elapsed         | 268         |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.025746994 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.189      |
# |    explained_variance   | 0.611       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 343         |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | -0.00144    |
# |    value_loss           | 480         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3712        |
# |    iterations           | 488         |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.005461151 |
# |    clip_fraction        | 0.0422      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.194      |
# |    explained_variance   | 0.584       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 308         |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | 0.00123     |
# |    value_loss           | 470         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3712        |
# |    iterations           | 489         |
# |    time_elapsed         | 269         |
# |    total_timesteps      | 1001472     |
# | train/                  |             |
# |    approx_kl            | 0.014596244 |
# |    clip_fraction        | 0.0817      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.188      |
# |    explained_variance   | 0.606       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 267         |
# |    n_updates            | 4880        |
# |    policy_gradient_loss | 0.0027      |
# |    value_loss           | 496         |
# -----------------------------------------

# %% [markdown]
# # Evaluation

# %%
env = gym.make('stocks-v0', df = df, frame_bound = (180,200), window_size = 5) # New Environment for Plotting
obs = env.reset()
while True: 
    obs = obs[np.newaxis, ...]
    action, _states = model.predict(obs) # Using Model to predict actions
    obs, rewards, done, info = env.step(action)
    if done:
        print("Info: ", info)
        break
# Out:
# Info:  {'total_reward': 27.28000000000003, 'total_profit': 1.096559363905186, 'position': 1}

# %%
plt.figure(figsize=(15,6))
plt.cla()
env.render_all()
plt.show()
